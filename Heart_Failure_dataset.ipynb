# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction
# 0    75.0        0                       582         0                 20  \
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction
# 0  75.0        0                       582         0                 20  \
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex
# 0                    1  265000.00               1.9           130    1  \
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes
# count  299.000000  299.000000                299.000000  299.000000  \
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets
# count         299.000000           299.000000     299.000000  \
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Que1
plt.figure()
sns.distplot(x=df['age'], bins=20, kde=True, rug=False)
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Distribution of Age among People with Heart Failure')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1192\3630640330.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['age'], bins=20, kde=True, rug=False)

# %%
df['DEATH_EVENT'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#Que2
plt.plot()
plt.xlabel("DEATH")
plt.ylabel("AGE")
plt.title("Most of the people died are between age 40-70")
sns.scatterplot(x='DEATH_EVENT',y='age',data=df)
# Out:
# <Axes: title={'center': 'Most of the people died are between age 40-70'}, xlabel='DEATH', ylabel='AGE'>

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
gender=df.sex.value_counts()

# %%
gender
# Out:
# sex
# 1    194
# 0    105
# Name: count, dtype: int64

# %%
#Que3
mylabel=["Male","Female"]
myexplode = [0.1, 0.0]
plt.title("Male Patients are more in number as compared to Females")
plt.pie(x=gender,labels = mylabel, explode = myexplode, autopct='%1.1f%%', shadow = True)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Que4
sns.scatterplot(x='age',y='platelets',data=df)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
#Que5
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
relation=pd.DataFrame(df['creatinine_phosphokinase'],df['serum_sodium'])

# %%
relation.corr()
# Out:
#                           creatinine_phosphokinase
# creatinine_phosphokinase                       1.0

# %%
sns.scatterplot(x='creatinine_phosphokinase',y='serum_sodium',data=relation)
# Out:
# <Axes: xlabel='creatinine_phosphokinase', ylabel='serum_sodium'>

# %%
#Que6
df['high_blood_pressure'].value_counts()
# Out:
# high_blood_pressure
# 0    194
# 1    105
# Name: count, dtype: int64

# %%
high_bp=df[['sex','high_blood_pressure']]

# %%
high_bp.value_counts(normalize=True)*100
# 20 % Male patient has high bp 
# 14% Female Patient has high bp
# Out:
# sex  high_blood_pressure
# 1    0                      44.481605
# 0    0                      20.401338
# 1    1                      20.401338
# 0    1                      14.715719
# Name: proportion, dtype: float64

# %%
#Que7
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
sm=df[['smoking','DEATH_EVENT']]
sm.value_counts()
# Out:
# smoking  DEATH_EVENT
# 0        0              137
#          1               66
# 1        0               66
#          1               30
# Name: count, dtype: int64

# %%
sm.corr()
# Out:
#               smoking  DEATH_EVENT
# smoking      1.000000    -0.012623
# DEATH_EVENT -0.012623     1.000000

# %%
sns.heatmap(sm.corr(),annot=True,cmap='coolwarm')
plt.title("People who smoke has less Death Event as compared to people who don't smoke")
# Out:
# Text(0.5, 1.0, "People who smoke has less Death Event as compared to people who don't smoke")

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Que9
sns.barplot(x='ejection_fraction',y='diabetes',data=df)
# Out:
# <Axes: xlabel='ejection_fraction', ylabel='diabetes'>

# %%
#Que8
sns.catplot(x='DEATH_EVENT',y='age',data=df)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Que10
sns.barplot(x='DEATH_EVENT',y='serum_creatinine',data=df)
plt.title("People who survived has low serum creatinine level as compared to people who died ")
plt.show()
