# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("student-por.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
sns.countplot(x='school',data=df)
#GP have higher number of students
plt.show()

# %%
sns.histplot(x=df.age,kde=True)
plt.title("Most common age group b/w 16 and 17")
plt.show()

# %%
df['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x=df['address'])
plt.title("Most of the students are from urban area")
plt.show()

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_counts=df.reason.value_counts()

# %%
plt.pie(reason_counts,labels=reason_counts.index,autopct="%1.1f%%",explode=[0.0,0.1,0,0.2,])
plt.title("Most of the student choose school for courses they provide")
plt.show()

# %%
act=df['activities'].value_counts()

# %%
plt.pie(act,labels=act.index,autopct="%1.1f%%",explode=[0.0,0.1])
plt.show()

# %%
df['Walc'].value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %%
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %%
sns.boxplot(df['freetime'])
# Out:
# <Axes: >

# %%
sns.histplot(df['studytime'])
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
df['absences'].unique()
# Out:
# array([ 4,  2,  6,  0, 10,  8, 16, 14,  1, 12, 24, 22, 32, 30, 21, 15,  9,
#        18, 26,  7, 11,  5, 13,  3], dtype=int64)

# %%
df['Pstatus']#A->away T->together
# Out:
# 0      A
# 1      T
# 2      T
# 3      T
# 4      T
#       ..
# 644    T
# 645    T
# 646    T
# 647    T
# 648    T
# Name: Pstatus, Length: 649, dtype: object

# %%
sns.countplot(data=df,x='Pstatus',hue='absences')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x=df['Fjob'])
plt.show()

# %%
sns.countplot(x=df['Mjob'])
plt.show()

# %%
df.hist(figsize=(30,40))
plt.show()

# %%
#bivariat analysis
sns.countplot(data=df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(10,30))
sns.pairplot(data=df)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.loc()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 df[num_col.corr()]
#
# TypeError: Series.corr() missing 1 required positional argument: 'other'
